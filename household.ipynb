# %%
import pandas as pd

# %%
data = pd.read_excel('data/2018/households/S5.2.xlsx')
years = data.iloc[3:4]
years
# Out:
#   विवरण 5.2: परिवार और सामान्य सरकार द्वारा व्यक्तिगत उपभोग व्यय (` करोड़)  \
# 3                                                NaN
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3        NaN    2011-12        NaN        NaN    2012-13        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 27 Unnamed: 28 Unnamed: 29  \
# 3        NaN    2013-14        NaN  ...         NaN         NaN     2015-16
#
#   Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 3         NaN         NaN     2016-17         NaN         NaN         NaN
#
#   Unnamed: 36
# 3         NaN
#
# [1 rows x 37 columns]

# %%
data
# Out:
#    विवरण 5.2: परिवार और सामान्य सरकार द्वारा व्यक्तिगत उपभोग व्यय (` करोड़)  \
# 0   Statement 5.2: Individual Consumption Expendit...
# 1                                                 NaN
# 2                                            क्र. सं.
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                   1
# 7                                                   2
# 8                                                   3
# 9                                                   4
# 10                                                  5
# 11                                                  6
# 12                                                  7
# 13                                                  8
# 14                                                  9
# 15                                                 10
# ...

# %%
process = data[6:]
process
# Out:
#    विवरण 5.2: परिवार और सामान्य सरकार द्वारा व्यक्तिगत उपभोग व्यय (` करोड़)  \
# 6                                                   1
# 7                                                   2
# 8                                                   3
# 9                                                   4
# 10                                                  5
# 11                                                  6
# 12                                                  7
# 13                                                  8
# 14                                                  9
# 15                                                 10
# 16                                                 11
# 17                                                 12
# 18                                                NaN
#
#                                      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 6           खाद्य एवं गैर-एल्‍कोहलिक पेय पदार्थ    1499739          0
# ...

# %%
process.iloc[0].values
# Out:
# array(['1', 'खाद्य एवं गैर-एल्\u200dकोहलिक पेय पदार्थ', 1499739, 0,
#        1499739, 1750949, 0, 1750949, 2060368, 0, 2060368, 2250584, 0,
#        2250584, 2365895, 0, 2365895, 1499739, 0, 1499739, 1590262, 0,
#        1590262, 1705929, 0, 1705929, 1726037, 0, 1726037, 1750052, 0,
#        1750052, 1912153, 0, 1912153, '1',
#        'Food and non-alcoholic beverages'], dtype=object)

# %%
labels = process.iloc[:, -1]
selected = labels.iloc[0]

# %%
headers = data.iloc[5][2:-2]
headers
# Out:
# Unnamed: 2          Household individual consumption expenditure
# Unnamed: 3     General government individual consumption expe...
# Unnamed: 4                         Actual individual consumption
# Unnamed: 5          Household individual consumption expenditure
# Unnamed: 6     General government individual consumption expe...
# Unnamed: 7                         Actual individual consumption
# Unnamed: 8          Household individual consumption expenditure
# Unnamed: 9     General government individual consumption expe...
# Unnamed: 10                        Actual individual consumption
# Unnamed: 11         Household individual consumption expenditure
# Unnamed: 12    General government individual consumption expe...
# Unnamed: 13                        Actual individual consumption
# Unnamed: 14         Household individual consumption expenditure
# Unnamed: 15    General government individual consumption expe...
# ...

# %%
selected
# Out:
# 'Food and non-alcoholic beverages'

# %%
row = process.iloc[0][2:-2].values
row
# Out:
# array([1499739, 0, 1499739, 1750949, 0, 1750949, 2060368, 0, 2060368,
#        2250584, 0, 2250584, 2365895, 0, 2365895, 1499739, 0, 1499739,
#        1590262, 0, 1590262, 1705929, 0, 1705929, 1726037, 0, 1726037,
#        1750052, 0, 1750052, 1912153, 0, 1912153], dtype=object)

# %%
labels.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-82c9f4195151> in <module>
# ----> 1 labels.index.value
#
# AttributeError: 'RangeIndex' object has no attribute 'value'

# %%
sections = process.iloc[:, -1]
sections
# Out:
# 6                      Food and non-alcoholic beverages
# 7            Alcoholic beverages, tobacco and narcotics
# 8                                 Clothing and footwear
# 9      Housing, water, electricity, gas and other fuels
# 10    Furnishings, household equipment and routine h...
# 11                                               Health
# 12                                            Transport
# 13                                        Communication
# 14                               Recreation and culture
# 15                                            Education
# 16                               Restaurants and hotels
# 17                     Miscellaneous goods and services
# 18                                                TOTAL
# Name: Unnamed: 36, dtype: object
